# %%
import tweepy
import random
import time
#from interactive_conditional_samples import interact_model
import gpt_2_simple as gpt2
from textblob import TextBlob

# %%
def pick_topic():
    topic = random.choice(['evolution', 'abortion', 'gun control', 'gay marriage', 'existence of god', 'healthcare'
                          , 'climate change', 'communism', '#christian'])
    return topic

def search(topic, api):
    results = api.search(q=topic, lang='en', result_type='recent', count=1)
#     for res in results:
#         if 
    return results
    
def generate_responses(text,sess, gpt2):
    print('Generating responses')
    responses = gpt2.generate(sess,
                              length=280,
                              temperature=0.8,
                              prefix=text+' ||| ',
                              nsamples=10,
                              batch_size=5,
                              return_as_list=True)
    print(responses)
    return responses

def select_response(responses):
    parsed = []
    for response in responses:
        response = response.split(' ||| ')[1]
        response = response[:240]
        response = response.split('<endoftext>')[0]
        before, sep, after = response.rpartition('.')
        response = before + sep
        parsed += [response]

    parsed = [x for x in parsed if 'emoticon' not in x and 'forum' not in x and x != '']
    sent_parsed = [[x,TextBlob(x).sentiment.polarity] for x in parsed]
    parsed.sort(key = lambda x: x[1], reverse = True)

    return parsed[0]

def reply(tweet, api,sess, gpt2):
    user = tweet._json['user']['screen_name']
    tweet_id = tweet._json['id_str']
    text = tweet._json['text']
    responses = generate_responses(text,sess, gpt2)
    reply_text = select_response(responses)
    
    #api.update_status('@' + user + ' ' + reply, in_reply_to_status_id=tweet_id)
    return text, reply_text

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run1')
# Out:
# Loading checkpoint checkpoint/run1/model-5047
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-5047

# %%
def main():
    auth = tweepy.OAuthHandler('5W4GMKnmBPmz73ofTbMSrBX5O', 'v3liOsP8k73qnqasUUbJAD0VaXyHJN6zy6tr2xdjdmuIgrjj0D')
    auth.set_access_token('977955567846281216-8YsIaPvhBtk3vQSZ5thkEvbiTTm39ro', 'h7JcHEceUN5PX8NuKYFA9f665DLMUSKpNizT1ZqFod2ei')

    api = tweepy.API(auth)
#     sess = gpt2.start_tf_sess()
#     gpt2.load_gpt2(sess, run_name='run1')
    while True:
        topic = pick_topic()
        tweet = search(topic, api)[0]
        text, reply_text = reply(tweet, api,sess, gpt2)
        print(topic)
        print('tweet: ', text)
        print('##########################')
        print('reply: ', reply_text)
        #time.sleep(int(random.random()*120+300))

# %%
main()
# Out:
# Generating responses
# ['RT @Malcolm_fleX48: I can\'t say this isn\'t expected from the party that thought pronouns, communism, and free stuff for noncitizens was a v… |||   Really? So you were being little in the "socialist nation" when the party decided to ban them from voting and proselytizing?  It goes back to my point. I\'m not a libertarian. I was introduced to them by my father when I was 8 years old, and it would seem that my family values is alive and well. I was introduced to the party by my sister when I was 9 and I voted for George W. Bush. I\'m not sure where your definition of the "party" comes from, but it would certainly not be what I came to the party for.     Is anyone in the US "socialist"? The party has been there a while.      I think it\'s a possibility that they were actually present at the party. I would expect a party to have a "key" so that people can vote. If there\'s no party then there\'s no chance of voting.  So you\'re the only one with a view about people voting? That\'s the extent of your argument, which is shallow.      You\'re the only one here who thinks that the "party" is irrelevant.      It\'s a free country. We have just become the most socialist country in the world.      It just hasn\'t been the best thing for *us', 'RT @Malcolm_fleX48: I can\'t say this isn\'t expected from the party that thought pronouns, communism, and free stuff for noncitizens was a v… |||   It\'s not like they\'re already saying that, and it\'s very early in the new year so they can\'t say this officially. But I think focusing on the issue of those who "cannot say" is a better way to refer to them.  Come back for me when they\'re better known. <endoftext>   My point exactly. And you haven\'t answered my question, have you? |||   I have on multiple occasions. And it is not my fault, but you\'re just going by what I say anyway. It\'s not my fault if you feel insulted, it\'s your own fault for not responding to the message. <endoftext>   No, I\'m saying this because you are in the wrong.  "All things are possible" is a statement that I have heard from several philosophers.  I am not claiming that it is a statement of fact, I am saying it is a statement of theory.  You are assuming that there is someone in this world who is saying that the universe is a black hole, to which I argued that yes, there is - the black hole I know the model you\'ve racked that is the mathematical model of what the universe is like, and I argued that provided it can be verified, I should be able to prove it in science.  And I have yet to see any proof that', 'RT @Malcolm_fleX48: I can\'t say this isn\'t expected from the party that thought pronouns, communism, and free stuff for noncitizens was a v… |||     Speaking of which, I think it would be a good idea to post this thread as a warning to anyone who might be tempted by possibly social democratic institutions of government: it would create a dumping ground for people who have followed the wrong paths of the past, and encourage others to dig deeper. It would also help to point out some of the problems with the new system, and what problems it has.     I think it would be a good idea to ask the well-meaning arguement that it is a problem for the right to use the toilet... which only works in most cases...     Let\'s hope you understand your own words... <endoftext>   "why"?   "you" (ex. your argument)   "that"   I couldn\'t have said it better myself...    Or maybe you shouldn\'t have said that, since "shallow" is a word again.    I\'m just saying, that it isn\'t that simple.     I don\'t think the "nope" argument is a good argument...       It\'s an attempt to judge the reply (and you) by your own words. |||  I don\'t know how many posts I am going to get today. I\'ll try.     We', 'RT @Malcolm_fleX48: I can\'t say this isn\'t expected from the party that thought pronouns, communism, and free stuff for noncitizens was a v… |||   There may be an element of truth to this but it is not a unanimous position - many  ...
# communism
# tweet:  RT @Malcolm_fleX48: I can't say this isn't expected from the party that thought pronouns, communism, and free stuff for noncitizens was a v…
# ##########################
# reply:  RT @Malcolm_fleX48: I can't say this isn't expected from the party that thought pronouns, communism, and free stuff for noncitizens was a v… |||   It's not expected from some people but it isn't obligated by law.
# Generating responses
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-14-5e1e31955dda> in main()
#       9         topic = pick_topic()
#      10         tweet = search(topic, api)[0]
# ---> 11         text, reply_text = reply(tweet, api,sess, gpt2)
#      12         print(topic)
#      13         print('tweet: ', text)
#
# <ipython-input-15-abf1ec2b49f8> in reply(tweet, api, sess, gpt2)
#      41     tweet_id = tweet._json['id_str']
#      42     text = tweet._json['text']
# ---> 43     responses = generate_responses(text,sess, gpt2)
#      44     reply_text = select_response(responses)
#      45
#
# <ipython-input-15-abf1ec2b49f8> in generate_responses(text, sess, gpt2)
#      18                               nsamples=10,
#      19                               batch_size=5,
# ---> 20                               return_as_list=True)
#      21     print(responses)
#      22     return responses
#
# ~/miniconda3/envs/mj/lib/python3.5/site-packages/gpt_2_simple/gpt_2.py in generate(sess, run_name, checkpoint_dir, model_name, model_dir, sample_dir, return_as_list, truncate, destination_path, sample_delim, prefix, seed, nsamples, batch_size, length, temperature, top_k, top_p, include_prefix)
#     449         else:
#     450             out = sess.run(output, feed_dict={
# --> 451                     context: batch_size * [context_tokens]
#     452                 })
#     453         for i in range(batch_size):
#
# ~/miniconda3/envs/mj/lib/python3.5/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/mj/lib/python3.5/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/miniconda3/envs/mj/lib/python3.5/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/mj/lib/python3.5/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/mj/lib/python3.5/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/mj/lib/python3.5/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
auth = tweepy.OAuthHandler('5W4GMKnmBPmz73ofTbMSrBX5O', 'v3liOsP8k73qnqasUUbJAD0VaXyHJN6zy6tr2xdjdmuIgrjj0D')
auth.set_access_token('977955567846281216-8YsIaPvhBtk3vQSZ5thkEvbiTTm39ro', 'h7JcHEceUN5PX8NuKYFA9f665DLMUSKpNizT1ZqFod2ei')

api = tweepy.API(auth)

# %%
s = search('gun control', api)

# %%
s[0]
# Out:
# Status(retweet_count=0, coordinates=None, user=User(lang=None, contributors_enabled=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, has_extended_profile=True, protected=False, profile_banner_url='https://pbs.twimg.com/profile_banners/2987150207/1571203765', created_at=datetime.datetime(2015, 1, 20, 11, 35, 18), translator_type='none', profile_text_color='333333', following=False, id=2987150207, default_profile=True, _json={'lang': None, 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'entities': {'description': {'urls': []}}, 'id_str': '2987150207', 'url': None, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'time_zone': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1184340779004649472/lP1hEVn4_normal.jpg', 'protected': False, 'profile_background_color': 'C0DEED', 'screen_name': 'SaikoWaifu03rd', 'translator_type': 'none', 'statuses_count': 2828, 'description': 'RPs: Eternally 18 y.o. Purple-haired Psycho-powered Idol Goddess\n\nIRL: Young Chinese woman who loves games esp. PC, CG, sleeveless dresses and the pre-woke left', 'notifications': False, 'has_extended_profile': True, 'is_translator': False, 'profile_text_color': '333333', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'favourites_count': 8248, 'id': 2987150207, 'default_profile': True, 'profile_link_color': '1DA1F2', 'contributors_enabled': False, 'utc_offset': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2987150207/1571203765', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1184340779004649472/lP1hEVn4_normal.jpg', 'followers_count': 135, 'verified': False, 'listed_count': 1, 'following': False, 'default_profile_image': False, 'is_translation_enabled': False, 'name': 'SaikoWaifu03rd - Death Stranded by Gears 5', 'created_at': 'Tue Jan 20 11:35:18 +0000 2015', 'profile_use_background_image': True, 'geo_enabled': False, 'follow_request_sent': False, 'location': 'Her Own Native Country', 'friends_count': 99}, profile_sidebar_border_color='C0DEED', utc_offset=None, favourites_count=8248, listed_count=1, default_profile_image=False, profile_use_background_image=True, name='SaikoWaifu03rd - Death Stranded by Gears 5', profile_sidebar_fill_color='DDEEF6', entities={'description': {'urls': []}}, id_str='2987150207', url=None, time_zone=None, notifications=False, profile_background_color='C0DEED', screen_name='SaikoWaifu03rd', statuses_count=2828, description='RPs: Eternally 18 y.o. Purple-haired Psycho-powered Idol Goddess\n\nIRL: Young Chinese woman who loves games esp. PC, CG, sleeveless dresses and the pre-woke left', is_translator=False, follow_request_sent=False, profile_image_url_https='https://pbs.twimg.com/profile_images/1184340779004649472/lP1hEVn4_normal.jpg', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_link_color='1DA1F2', profile_image_url='http://pbs.twimg.com/profile_images/1184340779004649472/lP1hEVn4_normal.jpg', verified=False, is_translation_enabled=False, followers_count=135, geo_enabled=False, friends_count=99, location='Her Own Native Country', _api=<tweepy.api.API object at 0x7efa7a49b710>), entities={'symbols': [], 'urls': [{'url': 'https://t.co/j2J3vyzqOK', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1195901596409856002', 'indices': [117, 140]}], 'user_mentions': [], 'hashtags': [{'text': 'TooFarLeft', 'indices': [44, 55]}]}, id_str='1195901596409856002', place=None, possibly_sensitive=False, quoted_status_id_str='1195440086965469186', source_url='http://twitter.com/download/iphone', retweeted=False, favorited=False, in_reply_to_user_id_str=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, geo=None, quoted_status_id=1195440086965469186, contributors=None, text ...
